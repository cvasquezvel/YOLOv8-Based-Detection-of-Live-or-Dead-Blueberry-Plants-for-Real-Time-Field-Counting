# %%
# import tempfile
# import os

# # Crear un directorio temporal
# temp_dir = tempfile.mkdtemp()

# # Realizar operaciones en el directorio temporal

# # Eliminar el directorio temporal y su contenido
# os.rmdir(temp_dir)

# %%
import os

# Cambiar el directorio de trabajo actual
os.chdir("G:\\Mi unidad\\Python\\Proyecto-vigor-defoliacion")

# Ahora, las rutas relativas se basarán en el nuevo directorio actual

# %%
# Obtener la ruta actual del directorio
current_directory = os.getcwd()
current_directory

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install tqdm

# %%
# !pip install scikit-learn

# %%
# !pip install pyyaml

# %%
#!pip install opencv-python==4.7.0.72
# !pip install opencv-python
#!conda remove opencv

# %%
import cv2
print(cv2.__file__)

# %%
import numpy as np 
import pandas as pd
import os
import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from glob import glob
from tqdm.notebook import tqdm
tqdm.pandas()
import random
import json
from sklearn.model_selection import train_test_split
import shutil
import yaml
plt.style.use("ggplot")

# %%
print(cv.__version__)

# %%
# !pip install --user roboflow

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="ysLbfsnaroQianBM7EmF")
# project = rf.workspace("inkastats-sac").project("blueberries-detection")
# dataset = project.version(4).download("coco")

# %%
BASE_DIR = "C:/Users/cvasquezv/Proyecto-vigor-defoliacion/input"
annotation_list = glob("C:/Users/cvasquezv/Proyecto-vigor-defoliacion/input/mortalidad/annotations/*.json")

# %%
data = pd.DataFrame()
data["annotation_dir"] = annotation_list

# %%
data

# %%
ruta_completa = "C:/Users/cvasquezv/Proyecto-vigor-defoliacion/input/4712331.FOTO.121358.jpg"
nombre_archivo = os.path.basename(ruta_completa)

print(nombre_archivo)

# %%
img_dir = "C:/Users/cvasquezv/Proyecto-vigor-defoliacion/input../../../input/4712331.FOTO.121358.jpg"
print("Antes de las sustituciones:", img_dir)

img_dir = img_dir.replace("/input../../../input/", "/").replace("/input../../", "/").replace("/input../", "/input/")
print("Después de las sustituciones:", img_dir)

# %%
import pandas as pd
import json
from glob import glob

def read_json_data(jsonfile):
    rows = {"img_dir":[] ,"img_w":[] , "img_h" : [], "sp_type": [] ,"xc":[] , "yc":[], "bb_height" : [] , "bb_width": [] , "bb_left":[] , "bb_top":[]}
    
    # read file
    with open(jsonfile) as json_f:
        json_data = json.load(json_f)

        img_dir = json_data["imagePath"].replace("\\", "/")
        #img_dir = img_dir.split("./input")[1]  # Corregir la construcción de la ruta

        img_dir = img_dir.replace("../../../input/", "/").replace("../../", "/").replace("..", "")
        #img_dir = img_dir.replace("../..", "/")
        
        sp_type = json_data["shapes"][0]["label"]

        img_w = json_data["imageWidth"]
        img_h = json_data["imageHeight"]

        # Normalize Bounding Box
        bb_points = json_data["shapes"][0]["points"]
        x1, y1 = bb_points[0]
        x2, y2 = bb_points[1]

        # Obtén las coordenadas del centro de la bounding box
        xc = (x1 + x2) / (2 * img_w)
        yc = (y1 + y2) / (2 * img_h)

        # Obtén el ancho y alto de la bounding box
        bb_width = abs(x2 - x1) / img_w
        bb_height = abs(y2 - y1) / img_h

        # Normalizar las coordenadas izquierda y superior de la bounding box
        bb_left = min(x1, x2) / img_w
        bb_top = min(y1, y2) / img_h

        rows["img_dir"].append(BASE_DIR + img_dir)
        rows["sp_type"].append(sp_type)
        rows["img_w"].append(img_w)
        rows["img_h"].append(img_h)
        rows["bb_height"].append(bb_height)
        rows["bb_width"].append(bb_width)
        rows["bb_left"].append(bb_left)
        rows["bb_top"].append(bb_top)
        rows["xc"].append(xc)
        rows["yc"].append(yc)

    return rows

data_list = []

for json_file in annotation_list:
    data_list.append(pd.DataFrame(read_json_data(json_file)))

df = pd.concat(data_list, ignore_index=True)
df.head()

# %%
#df = pd.concat(data_list, ignore_index=True)
#print(df)

# %%
#for json_file in tqdm(data["annotation_dir"]):
#    rows = read_json_data(json_file)
    
    # Crea un nuevo DataFrame a partir del diccionario y luego concaténalo con el DataFrame principal
#    df = pd.concat([df, pd.DataFrame.from_dict(rows)], ignore_index=True)

# Ahora df contiene todos los datos combinados

# %%
df = df.reset_index(drop=True)

df['sp_type'] = df['sp_type'].str.strip().replace({"0": "Dead", "1": "Alive"})

# %%
df.head()

# %%
df['img_dir'].head()

# %%
#!pip install openpyxl

# %%
import openpyxl

# Guardar el DataFrame en un archivo Excel
df.to_excel('data info.xlsx', index=False)  # Cambia 'nombre_del_archivo.xlsx' por el nombre que desees

# %%
df.sp_type.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Display Some examples

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def display_random_imgs(df, rows, cols):
    idxs = random.sample(df.index.tolist(), rows * cols)
    fig, ax = plt.subplots(rows, cols, figsize=(10, 10))

    if rows * cols != 1:
        for count, axs in enumerate(ax.flatten()):
            path = df.img_dir.iloc[idxs[count]]
            img = plt.imread(path)

            # Obtén las coordenadas normalizadas de la bounding box
            x = df.bb_left.iloc[idxs[count]]
            y = df.bb_top.iloc[idxs[count]]
            w = df.bb_width.iloc[idxs[count]]
            h = df.bb_height.iloc[idxs[count]]

            # Convierte las coordenadas normalizadas a píxeles
            x_pixel = x * df.img_w.iloc[idxs[count]]
            y_pixel = y * df.img_h.iloc[idxs[count]]
            w_pixel = w * df.img_w.iloc[idxs[count]]
            h_pixel = h * df.img_h.iloc[idxs[count]]

            # Crea el rectángulo
            patch = patches.Rectangle((x_pixel, y_pixel), w_pixel, h_pixel,
                                      linewidth=1, edgecolor='r', facecolor='none')

            axs.imshow(img)
            axs.add_patch(patch)
            axs.axis('off')
            axs.set_title(df.sp_type.iloc[idxs[count]])

    plt.show()

# Llamada a la función
# display_random_imgs(df, 2, 2)

# %%
display_random_imgs(df ,5, 3)

# %%
classes_name = ["Dead","Alive"]
classes_num = [0,1]

df.sp_type = df.sp_type.replace(classes_name , classes_num)

# %%
df.head()

# %%
from sklearn.model_selection import train_test_split

# Suponiendo que df es tu DataFrame original

# Dividir los datos en conjuntos de entrenamiento, validación y prueba
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
train_data, valid_data = train_test_split(train_data, test_size=0.25, random_state=42)  # El 25% de train para validación

# Ahora, 'train', 'val' y 'test' contienen los conjuntos de entrenamiento, validación y prueba respectivamente

# %%
import os

# Obtener el directorio actual del script
current_directory = os.getcwd()

# Crear directorios relativos al directorio actual
os.makedirs(os.path.join(current_directory, "working/data/train"), exist_ok=True)
os.makedirs(os.path.join(current_directory, "working/data/valid"), exist_ok=True)
os.makedirs(os.path.join(current_directory, "working/data/test"), exist_ok=True)

# %%
import os
import shutil
from tqdm import tqdm

# Asignar datos a los directorios correspondientes
def add_data_to_folder(file_type, data):
    for index, row in tqdm(data.iterrows(), total=len(data)):
        shutil.copy(row["img_dir"], f"working/data/{file_type}")
        with open(f'working/data/{file_type}/{row.img_dir.split("/")[-1][:-4]}.txt', "w") as f:
            f.write(str(row["sp_type"]))
            f.write(" ")
            f.write(str(row["xc"]))
            f.write(" ")
            f.write(str(row["yc"]))
            f.write(" ")
            f.write(str(row["bb_width"]))
            f.write(" ")
            f.write(str(row["bb_height"]))
            f.write("\n")

# %%
#def add_data_to_folder(file_type, data):
#    for index, row in tqdm(data.iterrows(), total=len(data)):
#        shutil.copy(row["img_dir"], f"working/data/{file_type}")
#        with open(f'working/data/{file_type}/{row.img_dir.split("/")[-1][:-4]}.txt', "w") as f:
#            f.write(str(row["sp_type"]))  # escribir la clase
#            f.write(" ")
#            f.write(str(row["bb_left"]))
#            f.write(" ")
#            f.write(str(row["bb_top"]))
#            f.write(" ")
#            f.write(str(row["bb_width"]))
#            f.write(" ")
#            f.write(str(row["bb_height"]))
#            f.write("\n")

# %%
import random

random.seed(123)  # Establece la semilla de aleatorización

# A continuación, puedes usar funciones de generación de números aleatorios, como random.randint(), etc.

# %%
# Luego puedes llamar a la función para cada conjunto de datos
# Asignar a train
add_data_to_folder("train", train_data)

# Asignar a valid
add_data_to_folder("valid", valid_data)

# Asignar a test
add_data_to_folder("test", test_data)

# %%
# create yml file
#yaml_dict = dict(
#    train = 'C:/Users/cvasquezv/kaggle/working/data/train',
#    val = 'C:/Users/cvasquezv/kaggle/working/data/test',
#    
#    nc    = len(classes_num), # number of classes
#    names = classes_name # classes
#    )

#with open('C:/Users/cvasquezv/kaggle/working/data.yaml', 'w') as outfile:
#    yaml.dump(yaml_dict, outfile, default_flow_style=False)

#%cat C:/Users/cvasquezv/kaggle/working/data.yaml

# %%
# !pip install pyyaml

# %%
import yaml

# Definir la información del YAML
yaml_data = {
    'train': 'C:\\Users\\cvasquezv\\Proyecto-vigor-defoliacion\\working\\data\\train\\',
    'val': 'C:\\Users\\cvasquezv\\Proyecto-vigor-defoliacion\\working\\data\\valid\\',
    #'test': 'C:\\Users\\cvasquezv\\Proyecto-vigor-defoliacion\\working\\data\\test\\',
    'nc': 2,
    'names': ["Dead","Alive"]#,
    # 'num': ["0","1"]
    
}

# Guardar el YAML en un archivo en el directorio working
yaml_file_path = 'C:\\Users\\cvasquezv\\Proyecto-vigor-defoliacion\\working\\data.yaml'
with open(yaml_file_path, 'w') as yaml_file:
    yaml.dump(yaml_data, yaml_file, default_flow_style=False)

print(f"Archivo YAML generado y guardado en: {yaml_file_path}")

# %%
with open('C:/Users/cvasquezv/Proyecto-vigor-defoliacion/working/data.yaml', 'r') as infile:
    yaml_content = infile.read()

print(yaml_content)

# %%
data_path = r'C:\Users\cvasquezv\Proyecto-vigor-defoliacion\working\data\train'

# Obtener la lista de archivos de anotación .txt en el directorio
annotation_files = [f for f in os.listdir(data_path) if f.endswith('.txt')]

# Crear un DataFrame para almacenar la información
df_train = pd.DataFrame(columns=['class'])

# Analizar cada archivo de anotación
for annotation_file in annotation_files:
    annotation_file_path = os.path.join(data_path, annotation_file)

    with open(annotation_file_path, 'r') as f:
        # Cada línea del archivo .txt representa una bounding box
        lines = f.readlines()

        for line in lines:
            # La primera columna en cada línea es el número de clase
            # Puedes adaptar esto según el formato específico de tus archivos de anotación
            class_number = line.split()[0]

            # Agregar la clase al DataFrame
            df_train = pd.concat([df_train, pd.DataFrame({'class': [class_number]})], ignore_index=True)

# Contar la frecuencia de cada clase
class_counts = df_train['class'].value_counts()

# Crear un gráfico de barras para visualizar la distribución de clases
plt.figure(figsize=(10, 6))
class_counts.plot(kind='bar', color='skyblue')
plt.title('Distribución de Clases en Conjunto de Datos YOLO')
plt.xlabel('Número de Clase')
plt.ylabel('Número de Bounding Boxes')
plt.show()

# Imprimir la tabla de frecuencia
print(class_counts)

# %%
df_train.head()

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
def display_images_with_rectangles(data_dir, rows, cols):
    # Obtén la lista de archivos de imágenes y anotaciones
    image_files = [f for f in os.listdir(data_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))]
    annotation_files = [f for f in os.listdir(data_dir) if f.lower().endswith('.txt')]

    # Filtra las imágenes que tienen anotaciones asociadas
    valid_image_files = [img for img in image_files if f"{os.path.splitext(img)[0]}.txt" in annotation_files]

    # Selecciona aleatoriamente las imágenes a mostrar
    selected_images = random.sample(valid_image_files, rows * cols)

    # Crea el subgráfico
    fig, ax = plt.subplots(rows, cols, figsize=(10, 10))

    if rows * cols != 1:
        for count, axs in enumerate(ax.flatten()):
            # Ruta de la imagen
            img_path = os.path.join(data_dir, selected_images[count])
            img = plt.imread(img_path)

            # Ruta del archivo de anotación
            annotation_path = os.path.join(data_dir, f"{os.path.splitext(selected_images[count])[0]}.txt")

            # Lee las coordenadas del archivo de anotación
            with open(annotation_path, 'r') as annotation_file:
                sp_type, xc, yc, bb_width, bb_height = annotation_file.readline().split()
                xc, yc, bb_width, bb_height = map(float, [xc, yc, bb_width, bb_height])

            # Convierte las coordenadas normalizadas a píxeles
            img_w, img_h = img.shape[1], img.shape[0]
            x_pixel = int(xc * img_w - (bb_width * img_w) / 2)
            y_pixel = int(yc * img_h - (bb_height * img_h) / 2)
            w_pixel = int(bb_width * img_w)
            h_pixel = int(bb_height * img_h)

            # Crea el rectángulo
            patch = patches.Rectangle((x_pixel, y_pixel), w_pixel, h_pixel,
                                      linewidth=1, edgecolor='r', facecolor='none')

            axs.imshow(img)
            axs.add_patch(patch)
            axs.axis('off')
            axs.set_title(f'{sp_type}')

    plt.show()

# %%
# Directorio que contiene los archivos de texto y las imágenes
data_directory = "C:\\Users\\cvasquezv\\Proyecto-vigor-defoliacion\\working\\data\\train"

# Visualizar imágenes aleatorias con bounding boxes
display_images_with_rectangles(data_directory, rows=5, cols=3)

# %%
del df , data

# %% [markdown]
# ## Yolo v8

# %%
#!pip install -U opencv-python
#!conda install -c conda-forge opencv=4.9

# %%
# !pip install -U ultralytics

# %%
#!pip install --upgrade pyyaml

# %%
import ultralytics
from IPython import display
display.clear_output()
# !yolo checks

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov8x.pt")  # load a pretrained model (recommended for training)

# %%
batch_size = 20
imgsz = 640

# %%
# Use the model
results = model.train(data="C:/Users/cvasquezv/Proyecto-vigor-defoliacion/working/data.yaml",
                      epochs=250,
                      batch = batch_size,
                      imgsz=imgsz)  # train the model

# %%
# Ruta al directorio que contiene las imágenes
ruta_imagenes = "working\\data\\test\\"

# %%
# Obtener la lista de archivos de imagen en el directorio
image_files = [f for f in os.listdir(ruta_imagenes) if f.endswith((".jpg", ".jpeg", ".png"))]

# Construir rutas completas de las imágenes
image_paths = [os.path.join(ruta_imagenes, file) for file in image_files]

# Ahora, image_paths contiene las rutas completas de las imágenes
print(image_paths)

# %%
from PIL import Image

# Lista de rutas a las nuevas imágenes
#image_paths = ['working\\data\\test\\002b37ac08e1.jpg',
#               'working\\data\\test\\002da3868a1a.jpg',
#               'working\\data\\test\\0036742ac4ec.jpg']
image_paths

# %%
# Cargar las imágenes
images = [Image.open(path) for path in image_paths]

# %%
# Realizar inferencias en las imágenes
inference = model.predict(images)

# %%
inference

# %%
print(dir(inference))

# %%
from PIL import Image

# Itera a través de las rutas de las imágenes
for image_path in image_paths:
    # Carga la imagen
    image = Image.open(image_path)
    
    # Preprocesa la imagen según sea necesario
    
    # Realiza la inferencia
    results = model.predict(image,
                            save=True,
                            save_crop=True,
                            save_txt=True,
                            imgsz=640,
                            conf=0.1,
                            max_det=300)
    
    # Postprocesa los resultados y visualiza o almacena la salida según tus necesidades

# %%
from PIL import Image

# Itera a través de las rutas de las imágenes
for image_path in image_paths:
    # Carga la imagen
    image = Image.open(image_path)
    
    # Realiza la inferencia
    results = model.predict(image)
    
    # Show the results for this image
    for r in results:
        im_array = r.plot()  # plot a BGR numpy array of predictions
        im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
        im.show()  # show image

# %%
#!pip install ultralytics==8.0.175
#!pip install ultralytics
#!pip install ultralytics==8.0.213

# %%
#!pip install ruamel.yaml

# %%
#!conda update -n myenv opencv-python

# %%
#import sys
#sys.path.append(r'C:\Users\cvasquezv\Anaconda3\envs\myenv\Lib\site-packages')

import cv2
print(cv2.__version__)

from ultralytics import YOLO

# %%
# Load the YOLOv8 model
model = YOLO("G:/Mi unidad/Python/Proyecto-vigor-defoliacion/runs/detect/train8/weights/best.pt/")

# %% [markdown]
# ## Ver inferencias del modelo

# %%
# Open the video file
video_path = "8.mp4"
cap = cv2.VideoCapture(video_path)

screen_width = 800  # Reemplaza con la resolución de tu pantalla
screen_height = 600  # Reemplaza con la resolución de tu pantalla

# %%
# Obtener las propiedades del video (ancho, alto, fps)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Porcentaje de reducción de tamaño de la ventana
reduction_percentage = 40

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the original frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Reduce the size of the frame for display
        small_frame = cv2.resize(annotated_frame, (int(width * reduction_percentage / 100), int(height * reduction_percentage / 100)))

        # Display the annotated frame with reduced window size
        cv2.imshow("YOLOv8 Inference", small_frame)

        # Reduce the delay for higher FPS
        cv2.waitKey(int(1000 / fps))  # Set a delay based on the original video's FPS

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Guardar video con conteo y dimensiones reales

# %%
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import cv2
import numpy as np

# Open the video file
video_path = "8.mp4"
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Percentage reduction of window size
reduction_percentage = 40

# Define region points in a vertical orientation
region_points = [(w*0.40, 0), (w*0.40, h), 
                 (w*0.50, h), (w*0.50, 0)]  # Ajusta las coordenadas según tus preferencias

classes_to_count = [0, 1]

# Video writer
video_writer = cv2.VideoWriter("object_counting_output.avi",
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       fps,
                       (w, h))


# Init Object Counter
counter = object_counter.ObjectCounter()
# Ejemplo de reinicio manual del contador
counter.counter_variable = 0

counter.set_args(view_img=False,
                 reg_pts=region_points,
                 #view_in_counts = True,
                 #view_out_counts = True,
                 classes_names=model.model.names,
                 draw_tracks=True
                 )

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("El frame del video está vacío o el procesamiento del video se ha completado correctamente.")
        break
    tracks = model.track(im0, persist=True, show=False, classes=classes_to_count)

    # Inicia el conteo y obtén el número de objetos contados por clase
    counts_by_class = counter.start_counting(im0, tracks)

    # Reduce el tamaño de la imagen para su visualización
    small_frame = cv2.resize(im0, (int(w * reduction_percentage / 100), int(h * reduction_percentage / 100)))

    # Escribe el frame en el archivo de video
    video_writer.write(im0)

    # Muestra la imagen reducida
    cv2.imshow("Object Counting", small_frame)

    # Rompe el bucle si se presiona 'q'
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# %%
cap.release()
video_writer.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Conteo y tracker multiclase con Yolov8

# %%
import cv2
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import csv


model = YOLO("G:/Mi unidad/Python/Proyecto-vigor-defoliacion/runs/detect/train8/weights/best.pt/")

# Open the video file
video_path = "8.mp4"
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Percentage reduction of window size
reduction_percentage = 40

# Define region points in a vertical orientation
region_points = [(w*0.40, 0), (w*0.40, h), 
                 (w*0.50, h), (w*0.50, 0)]  # Ajusta las coordenadas según tus preferencias


classes_to_count = [0, 1]

# Clases a contar (Dead y Alive)
classes_to_count_dead = [0]  # Reemplaza con el índice correcto de la clase "Dead"
classes_to_count_alive = [1]  # Reemplaza con el índice correcto de la clase "Alive"

# Video writer
video_writer = cv2.VideoWriter("object_counting_multiclass.avi",
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       fps,
                       (w, h))

# Init Object Counters for each class
counter_dead = object_counter.ObjectCounter()
counter_dead.counter_variable = 0
counter_dead.set_args(view_img=False,
                      view_in_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia adentro
                      view_out_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia afuera
                      reg_pts=region_points,
                      classes_names=model.model.names,
                      draw_tracks=True)

counter_alive = object_counter.ObjectCounter()
counter_alive.counter_variable = 0
counter_alive.set_args(view_img=False,
                       view_in_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia adentro
                       view_out_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia afuera
                       reg_pts=region_points,
                       classes_names=model.model.names,
                       draw_tracks=True)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("El frame del video está vacío o el procesamiento del video se ha completado correctamente.")
        break

    # Inicia el conteo y obtén el número de objetos contados por clase
    #tracks_dead = model.track(im0, persist=True, show=False, classes=classes_to_count_dead)
    #counts_dead = counter_dead.start_counting(im0, tracks_dead)

    #tracks_alive = model.track(im0, persist=True, show=False, classes=classes_to_count_alive)
    #counts_alive = counter_alive.start_counting(im0, tracks_alive)

    # Create a dictionary to map class labels to counters
    counters_by_class = {"Dead": counter_dead, "Alive": counter_alive}

    # Inicia el conteo y obtén el número de objetos contados por clase
    tracks_dead = model.track(im0, persist=True, show=False, classes=classes_to_count_dead)
    counts_dead = counters_by_class["Dead"].start_counting(im0, tracks_dead)

    tracks_alive = model.track(im0, persist=True, show=False, classes=classes_to_count_alive)
    counts_alive = counters_by_class["Alive"].start_counting(im0, tracks_alive)

    # Dead Count
    text_dead = f'Dead: {counter_dead.out_counts}'
    font_dead = cv2.FONT_HERSHEY_SIMPLEX
    font_scale_dead = 2
    font_thickness_dead = 4
    font_color_dead = (0, 0, 255)
    background_color_dead = (0, 0, 0)

    # Get the size of the text
    (text_width_dead, text_height_dead), _ = cv2.getTextSize(text_dead, font_dead, font_scale_dead, font_thickness_dead)

    # Set the position for the text
    text_position_dead = (10, 60)

    # Create a black background for the text
    background_rect_dead = (text_position_dead[0], text_position_dead[1] - text_height_dead, text_width_dead, text_height_dead)
    cv2.rectangle(im0, background_rect_dead, background_color_dead, thickness=cv2.FILLED)

    # Put the text on the image
    cv2.putText(im0, text_dead, text_position_dead, font_dead, font_scale_dead, font_color_dead, font_thickness_dead, cv2.LINE_AA)

    # Alive Count
    text_alive = f'Alive: {counter_alive.out_counts}'
    font_alive = cv2.FONT_HERSHEY_SIMPLEX
    font_scale_alive = 2
    font_thickness_alive = 4
    font_color_alive = (0, 255, 0)
    background_color_alive = (0, 0, 0)

    # Get the size of the text
    (text_width_alive, text_height_alive), _ = cv2.getTextSize(text_alive, font_alive, font_scale_alive, font_thickness_alive)

    # Set the position for the text
    text_position_alive = (10, 110)

    # Create a black background for the text
    background_rect_alive = (text_position_alive[0], text_position_alive[1] - text_height_alive, text_width_alive, text_height_alive)
    cv2.rectangle(im0, background_rect_alive, background_color_alive, thickness=cv2.FILLED)

    # Put the text on the image
    cv2.putText(im0, text_alive, text_position_alive, font_alive, font_scale_alive, font_color_alive, font_thickness_alive, cv2.LINE_AA)

    # Añade el texto con los conteos a la imagen
    #cv2.putText(im0, f'Dead: {counter_dead.out_counts}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
    #cv2.putText(im0, f'Alive: {counter_alive.out_counts}', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

    # Reduce el tamaño de la imagen para su visualización
    small_frame = cv2.resize(im0, (int(w * reduction_percentage / 100), int(h * reduction_percentage / 100)))
    
    # Escribe el frame en el archivo de video
    video_writer.write(im0)

    # Muestra la imagen reducida
    cv2.imshow("Object Counting", small_frame)

    # Rompe el bucle si se presiona 'q'
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# %%
cap.release()
video_writer.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Conteo, Tracker y Registro de múltiples clases

# %%
import cv2
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import csv
import pandas as pd
import openpyxl

model = YOLO("G:/Mi unidad/Python/Proyecto-vigor-defoliacion/runs/detect/train8/weights/best.pt/")

# Open the video file
video_path = "8.mp4"
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Percentage reduction of window size
reduction_percentage = 40

# Define region points in a vertical orientation
region_points = [(w*0.40, 0), (w*0.40, h), 
                 (w*0.50, h), (w*0.50, 0)]  # Ajusta las coordenadas según tus preferencias

classes_to_count = [0, 1]

# Clases a contar (Dead y Alive)
classes_to_count_dead = [0]  # Reemplaza con el índice correcto de la clase "Dead"
classes_to_count_alive = [1]  # Reemplaza con el índice correcto de la clase "Alive"

# Video writer
video_writer = cv2.VideoWriter("object_counting_multiclass.avi",
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       fps,
                       (w, h))

# Init Object Counters for each class
counter_dead = object_counter.ObjectCounter()
counter_dead.counter_variable = 0
counter_dead.set_args(view_img=False,
                      view_in_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia adentro
                      view_out_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia afuera
                      reg_pts=region_points,
                      classes_names=model.model.names,
                      draw_tracks=True)

counter_alive = object_counter.ObjectCounter()
counter_alive.counter_variable = 0
counter_alive.set_args(view_img=False,
                       view_in_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia adentro
                       view_out_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia afuera
                       reg_pts=region_points,
                       classes_names=model.model.names,
                       draw_tracks=True)

counter_all = object_counter.ObjectCounter()
counter_all.counter_variable = 0
counter_all.set_args(view_img=False,
                     view_in_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia adentro
                     view_out_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia afuera
                     reg_pts=region_points,
                     classes_names=model.model.names,
                     draw_tracks=False)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("El frame del video está vacío o el procesamiento del video se ha completado correctamente.")
        break

    # Inicia el conteo y obtén el número de objetos contados por clase
    #tracks_dead = model.track(im0, persist=True, show=False, classes=classes_to_count_dead)
    #counts_dead = counter_dead.start_counting(im0, tracks_dead)

    #tracks_alive = model.track(im0, persist=True, show=False, classes=classes_to_count_alive)
    #counts_alive = counter_alive.start_counting(im0, tracks_alive)

    # Create a dictionary to map class labels to counters
    counters_by_class = {"Dead": counter_dead, "Alive": counter_alive, "All": counter_all}

    # Inicia el conteo y obtén el número de objetos contados por clase
    tracks_dead = model.track(im0, persist=True, show=False, classes=classes_to_count_dead,
                               conf = 0.4, iou = 0.2, verbose = True)
    counts_dead = counters_by_class["Dead"].start_counting(im0, tracks_dead)

    tracks_alive = model.track(im0, persist=True, show=False, classes=classes_to_count_alive,
                                conf = 0.5, iou = 0.2, verbose = True)
    counts_alive = counters_by_class["Alive"].start_counting(im0, tracks_alive)

    tracks_all = model.track(im0, persist=True, show=False,
                                conf = 0.5, iou = 0.2, verbose = True)
    counts_all = counters_by_class["All"].start_counting(im0, tracks_all)

    # Dead Count
    text_dead = f'Dead: {counter_dead.out_counts}'
    font_dead = cv2.FONT_HERSHEY_SIMPLEX
    font_scale_dead = 2
    font_thickness_dead = 4
    font_color_dead = (0, 0, 255)
    background_color_dead = (0, 0, 0)

    # Get the size of the text
    (text_width_dead, text_height_dead), _ = cv2.getTextSize(text_dead, font_dead, font_scale_dead, font_thickness_dead)

    # Set the position for the text
    text_position_dead = (10, 60)

    # Create a black background for the text
    background_rect_dead = (text_position_dead[0], text_position_dead[1] - text_height_dead, text_width_dead, text_height_dead)
    cv2.rectangle(im0, background_rect_dead, background_color_dead, thickness=cv2.FILLED)

    # Put the text on the image
    cv2.putText(im0, text_dead, text_position_dead, font_dead, font_scale_dead, font_color_dead, font_thickness_dead, cv2.LINE_AA)

    # Alive Count
    text_alive = f'Alive: {counter_alive.out_counts}'
    font_alive = cv2.FONT_HERSHEY_SIMPLEX
    font_scale_alive = 2
    font_thickness_alive = 4
    font_color_alive = (0, 255, 0)
    background_color_alive = (0, 0, 0)

    # Get the size of the text
    (text_width_alive, text_height_alive), _ = cv2.getTextSize(text_alive, font_alive, font_scale_alive, font_thickness_alive)

    # Set the position for the text
    text_position_alive = (10, 110)

    # Create a black background for the text
    background_rect_alive = (text_position_alive[0], text_position_alive[1] - text_height_alive, text_width_alive, text_height_alive)
    cv2.rectangle(im0, background_rect_alive, background_color_alive, thickness=cv2.FILLED)

    # Put the text on the image
    cv2.putText(im0, text_alive, text_position_alive, font_alive, font_scale_alive, font_color_alive, font_thickness_alive, cv2.LINE_AA)

    # Añade el texto con los conteos a la imagen
    #cv2.putText(im0, f'Dead: {counter_dead.out_counts}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
    #cv2.putText(im0, f'Alive: {counter_alive.out_counts}', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

    # Guardar conteos en stream en un archivo Excel
    data_dead = {'id': counter_dead.counting_list, 'class': 'dead'}
    df_dead = pd.DataFrame(data_dead)

    data_alive = {'id': counter_alive.counting_list, 'class': 'alive'}
    df_alive = pd.DataFrame(data_alive)

    df_combined = pd.concat([df_dead, df_alive], ignore_index=True)
    df_combined = df_combined.sort_values(by='id')

    excel_filename = 'combined_counts.xlsx'
    df_combined.to_excel(excel_filename, index=False)

    # Reduce el tamaño de la imagen para su visualización
    small_frame = cv2.resize(im0, (int(w * reduction_percentage / 100), int(h * reduction_percentage / 100)))
    
    # Escribe el frame en el archivo de video
    video_writer.write(im0)

    # Muestra la imagen reducida
    cv2.imshow("Object Counting", small_frame)

    # Rompe el bucle si se presiona 'q'
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
# Out:
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
#
# 0: 640x384 1 Dead, 1126.6ms
# Speed: 3.0ms preprocess, 1126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1057.7ms
# Speed: 3.0ms preprocess, 1057.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1107.4ms
# Speed: 2.8ms preprocess, 1107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1063.5ms
# Speed: 2.0ms preprocess, 1063.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1075.2ms
# Speed: 3.0ms preprocess, 1075.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1175.7ms
# Speed: 2.0ms preprocess, 1175.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1316.4ms
# Speed: 0.0ms preprocess, 1316.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1113.7ms
# Speed: 2.4ms preprocess, 1113.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 985.4ms
# Speed: 2.0ms preprocess, 985.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1136.4ms
# Speed: 0.0ms preprocess, 1136.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1599.8ms
# Speed: 0.0ms preprocess, 1599.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1892.4ms
# Speed: 3.1ms preprocess, 1892.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1678.0ms
# Speed: 3.3ms preprocess, 1678.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1680.7ms
# Speed: 3.9ms preprocess, 1680.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1758.7ms
# Speed: 4.6ms preprocess, 1758.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1062.6ms
# Speed: 4.4ms preprocess, 1062.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 975.0ms
# Speed: 3.0ms preprocess, 975.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1014.7ms
# Speed: 2.0ms preprocess, 1014.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1015.2ms
# Speed: 10.5ms preprocess, 1015.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1049.4ms
# Speed: 3.4ms preprocess, 1049.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1058.2ms
# Speed: 4.6ms preprocess, 1058.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1161.8ms
# Speed: 3.5ms preprocess, 1161.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1248.3ms
# Speed: 2.7ms preprocess, 1248.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1147.0ms
# Speed: 1.4ms preprocess, 1147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1727.0ms
# Speed: 4.0ms preprocess, 1727.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1592.1ms
# Speed: 4.9ms preprocess, 1592.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1683.4ms
# Speed: 3.1ms preprocess, 1683.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1704.5ms
# Speed: 11.2ms preprocess, 1704.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1735.8ms
# Speed: 0.0ms preprocess, 1735.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1642.5ms
# Speed: 15.0ms preprocess, 1642.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1145.9ms
# Speed: 0.0ms preprocess, 1145.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1049.5ms
# Speed: 5.2ms preprocess, 1049.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1043.7ms
# Speed: 2.8ms preprocess, 1043.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1034.3ms
# Speed: 2.1ms preprocess, 1034.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 954.2ms
# Speed: 3.4ms preprocess, 954.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 994.1ms
# Speed: 0.0ms preprocess, 994.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 998.8ms
# Speed: 0.0ms preprocess, 998.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 994.7ms
# Speed: 0.0ms preprocess, 994.7ms inference, 15.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 977.9ms
# Speed: 0.0ms preprocess, 977.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1614.2ms
# Speed: 0.0ms preprocess, 1614.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1797.5ms
# Speed: 1.3ms preprocess, 1797.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1664.4ms
# Speed: 2.7ms preprocess, 1664.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1056.8ms
# Speed: 2.6ms preprocess, 1056.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1007.6ms
# Speed: 9.7ms preprocess, 1007.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1052.2ms
# Speed: 2.5ms preprocess, 1052.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1066.4ms
# Speed: 0.7ms preprocess, 1066.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 976.5ms
# Speed: 2.0ms preprocess, 976.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 951.7ms
# Speed: 16.4ms preprocess, 951.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 985.1ms
# Speed: 3.0ms preprocess, 985.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1041.2ms
# Speed: 12.5ms preprocess, 1041.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 969.9ms
# Speed: 3.0ms preprocess, 969.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1563.9ms
# Speed: 2.0ms preprocess, 1563.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1766.3ms
# Speed: 0.0ms preprocess, 1766.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1851.2ms
# Speed: 0.0ms preprocess, 1851.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1013.2ms
# Speed: 3.8ms preprocess, 1013.2ms inference, 17.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1024.7ms
# Speed: 2.7ms preprocess, 1024.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1200.6ms
# Speed: 0.0ms preprocess, 1200.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1139.7ms
# Speed: 10.3ms preprocess, 1139.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1032.4ms
# Speed: 1.3ms preprocess, 1032.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1029.4ms
# Speed: 0.2ms preprocess, 1029.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1084.1ms
# Speed: 0.0ms preprocess, 1084.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1145.4ms
# Speed: 2.3ms preprocess, 1145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1348.2ms
# Speed: 2.0ms preprocess, 1348.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1667.0ms
# Speed: 0.0ms preprocess, 1667.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1717.3ms
# Speed: 0.0ms preprocess, 1717.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1797.7ms
# Speed: 5.6ms preprocess, 1797.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1080.5ms
# Speed: 4.2ms preprocess, 1080.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1132.7ms
# Speed: 1.1ms preprocess, 1132.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1143.1ms
# Speed: 0.0ms preprocess, 1143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1059.3ms
# Speed: 2.5ms preprocess, 1059.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1143.6ms
# Speed: 0.0ms preprocess, 1143.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 998.0ms
# Speed: 0.0ms preprocess, 998.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1049.2ms
# Speed: 15.6ms preprocess, 1049.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1292.7ms
# Speed: 3.1ms preprocess, 1292.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1080.4ms
# Speed: 2.0ms preprocess, 1080.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1119.1ms
# Speed: 4.5ms preprocess, 1119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1117.2ms
# Speed: 0.0ms preprocess, 1117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1016.3ms
# Speed: 0.0ms preprocess, 1016.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Deads, 1429.3ms
# Speed: 0.0ms preprocess, 1429.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1704.4ms
# Speed: 13.0ms preprocess, 1704.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1559.3ms
# Speed: 0.0ms preprocess, 1559.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1622.4ms
# Speed: 0.0ms preprocess, 1622.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1666.3ms
# Speed: 0.0ms preprocess, 1666.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1672.3ms
# Speed: 0.0ms preprocess, 1672.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Deads, 1780.2ms
# Speed: 0.0ms preprocess, 1780.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1738.1ms
# Speed: 0.0ms preprocess, 1738.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1644.3ms
# Speed: 3.4ms preprocess, 1644.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Deads, 1029.2ms
# Speed: 2.2ms preprocess, 1029.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1043.9ms
# Speed: 0.0ms preprocess, 1043.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1048.7ms
# Speed: 3.9ms preprocess, 1048.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1108.0ms
# Speed: 5.3ms preprocess, 1108.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1072.1ms
# Speed: 3.2ms preprocess, 1072.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1025.9ms
# Speed: 2.0ms preprocess, 1025.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1034.0ms
# Speed: 2.4ms preprocess, 1034.0ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1000.5ms
# Speed: 0.0ms preprocess, 1000.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1156.1ms
# Speed: 0.0ms preprocess, 1156.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1709.0ms
# Speed: 0.0ms preprocess, 1709.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1440.5ms
# Speed: 3.1ms preprocess, 1440.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1745.1ms
# Speed: 5.0ms preprocess, 1745.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1056.7ms
# Speed: 3.1ms preprocess, 1056.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1112.0ms
# Speed: 0.0ms preprocess, 1112.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1144.8ms
# Speed: 2.0ms preprocess, 1144.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1041.9ms
# Speed: 4.0ms preprocess, 1041.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1074.7ms
# Speed: 2.0ms preprocess, 1074.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1082.2ms
# Speed: 2.5ms preprocess, 1082.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1092.8ms
# Speed: 3.6ms preprocess, 1092.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 986.2ms
# Speed: 2.1ms preprocess, 986.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1000.6ms
# Speed: 0.0ms preprocess, 1000.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1116.6ms
# Speed: 0.0ms preprocess, 1116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1056.6ms
# Speed: 0.0ms preprocess, 1056.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 990.1ms
# Speed: 0.0ms preprocess, 990.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1053.5ms
# Speed: 2.2ms preprocess, 1053.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1041.0ms
# Speed: 0.0ms preprocess, 1041.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 956.6ms
# Speed: 0.0ms preprocess, 956.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1011.4ms
# Speed: 0.0ms preprocess, 1011.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 966.3ms
# Speed: 0.0ms preprocess, 966.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 985.9ms
# Speed: 0.0ms preprocess, 985.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1255.4ms
# Speed: 0.0ms preprocess, 1255.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1170.5ms
# Speed: 4.0ms preprocess, 1170.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1202.6ms
# Speed: 1.2ms preprocess, 1202.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1047.0ms
# Speed: 4.0ms preprocess, 1047.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1060.4ms
# Speed: 2.0ms preprocess, 1060.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1045.1ms
# Speed: 0.0ms preprocess, 1045.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Deads, 1070.0ms
# Speed: 0.0ms preprocess, 1070.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1068.2ms
# Speed: 0.0ms preprocess, 1068.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1094.2ms
# Speed: 0.0ms preprocess, 1094.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1050.7ms
# Speed: 15.3ms preprocess, 1050.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1063.6ms
# Speed: 17.1ms preprocess, 1063.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1084.4ms
# Speed: 0.0ms preprocess, 1084.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1105.8ms
# Speed: 2.0ms preprocess, 1105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1017.1ms
# Speed: 0.0ms preprocess, 1017.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1090.4ms
# Speed: 0.0ms preprocess, 1090.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1166.9ms
# Speed: 0.0ms preprocess, 1166.9ms inference, 16.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1065.0ms
# Speed: 1.7ms preprocess, 1065.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1074.5ms
# Speed: 2.6ms preprocess, 1074.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1032.4ms
# Speed: 0.0ms preprocess, 1032.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1023.4ms
# Speed: 3.0ms preprocess, 1023.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1018.0ms
# Speed: 0.0ms preprocess, 1018.0ms inference, 16.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 976.0ms
# Speed: 0.5ms preprocess, 976.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 982.0ms
# Speed: 0.0ms preprocess, 982.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1002.3ms
# Speed: 4.0ms preprocess, 1002.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1001.6ms
# Speed: 0.0ms preprocess, 1001.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1048.2ms
# Speed: 3.8ms preprocess, 1048.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1019.1ms
# Speed: 0.0ms preprocess, 1019.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1030.2ms
# Speed: 4.0ms preprocess, 1030.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1163.8ms
# Speed: 16.5ms preprocess, 1163.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1179.9ms
# Speed: 3.7ms preprocess, 1179.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1152.0ms
# Speed: 3.4ms preprocess, 1152.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1076.4ms
# Speed: 2.0ms preprocess, 1076.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1047.9ms
# Speed: 2.0ms preprocess, 1047.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1045.4ms
# Speed: 2.0ms preprocess, 1045.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1038.4ms
# Speed: 0.0ms preprocess, 1038.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1407.4ms
# Speed: 0.0ms preprocess, 1407.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1196.1ms
# Speed: 0.0ms preprocess, 1196.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1140.2ms
# Speed: 2.9ms preprocess, 1140.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1063.8ms
# Speed: 2.0ms preprocess, 1063.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1094.3ms
# Speed: 3.0ms preprocess, 1094.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1761.6ms
# Speed: 3.0ms preprocess, 1761.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1566.2ms
# Speed: 3.7ms preprocess, 1566.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1555.2ms
# Speed: 4.9ms preprocess, 1555.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1730.5ms
# Speed: 4.6ms preprocess, 1730.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1611.8ms
# Speed: 3.0ms preprocess, 1611.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1059.6ms
# Speed: 0.0ms preprocess, 1059.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1028.5ms
# Speed: 2.0ms preprocess, 1028.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1014.7ms
# Speed: 0.0ms preprocess, 1014.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1023.4ms
# Speed: 15.2ms preprocess, 1023.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1034.0ms
# Speed: 2.0ms preprocess, 1034.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 970.2ms
# Speed: 2.7ms preprocess, 970.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 962.1ms
# Speed: 2.6ms preprocess, 962.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 984.0ms
# Speed: 12.5ms preprocess, 984.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1044.9ms
# Speed: 0.0ms preprocess, 1044.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1533.4ms
# Speed: 4.2ms preprocess, 1533.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1599.2ms
# Speed: 0.0ms preprocess, 1599.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1876.5ms
# Speed: 4.0ms preprocess, 1876.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1144.7ms
# Speed: 1.1ms preprocess, 1144.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 965.8ms
# Speed: 0.0ms preprocess, 965.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1070.1ms
# Speed: 2.9ms preprocess, 1070.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 987.0ms
# Speed: 3.0ms preprocess, 987.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1032.2ms
# Speed: 3.0ms preprocess, 1032.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 996.2ms
# Speed: 3.5ms preprocess, 996.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1031.2ms
# Speed: 0.0ms preprocess, 1031.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1004.5ms
# Speed: 3.9ms preprocess, 1004.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1056.5ms
# Speed: 0.0ms preprocess, 1056.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1525.7ms
# Speed: 0.0ms preprocess, 1525.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1578.4ms
# Speed: 0.0ms preprocess, 1578.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1683.3ms
# Speed: 1.0ms preprocess, 1683.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1716.5ms
# Speed: 1.3ms preprocess, 1716.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1734.3ms
# Speed: 14.4ms preprocess, 1734.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1500.8ms
# Speed: 0.0ms preprocess, 1500.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1057.7ms
# Speed: 4.0ms preprocess, 1057.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1109.6ms
# Speed: 2.9ms preprocess, 1109.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1043.8ms
# Speed: 1.1ms preprocess, 1043.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1026.1ms
# Speed: 8.5ms preprocess, 1026.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1043.8ms
# Speed: 3.7ms preprocess, 1043.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1009.8ms
# Speed: 3.3ms preprocess, 1009.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1016.5ms
# Speed: 2.9ms preprocess, 1016.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1031.1ms
# Speed: 0.0ms preprocess, 1031.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1100.3ms
# Speed: 3.6ms preprocess, 1100.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1738.9ms
# Speed: 4.5ms preprocess, 1738.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1605.4ms
# Speed: 4.0ms preprocess, 1605.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1668.4ms
# Speed: 0.0ms preprocess, 1668.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1084.7ms
# Speed: 2.1ms preprocess, 1084.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 999.9ms
# Speed: 0.0ms preprocess, 999.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 964.7ms
# Speed: 3.0ms preprocess, 964.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 950.0ms
# Speed: 16.6ms preprocess, 950.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 993.0ms
# Speed: 0.0ms preprocess, 993.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1233.1ms
# Speed: 2.4ms preprocess, 1233.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1141.4ms
# Speed: 3.2ms preprocess, 1141.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1209.8ms
# Speed: 3.0ms preprocess, 1209.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1281.9ms
# Speed: 2.5ms preprocess, 1281.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1819.0ms
# Speed: 0.0ms preprocess, 1819.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1557.6ms
# Speed: 0.6ms preprocess, 1557.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1128.0ms
# Speed: 3.0ms preprocess, 1128.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 954.4ms
# Speed: 2.2ms preprocess, 954.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1033.3ms
# Speed: 0.0ms preprocess, 1033.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1032.0ms
# Speed: 2.9ms preprocess, 1032.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 992.1ms
# Speed: 1.2ms preprocess, 992.1ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1089.7ms
# Speed: 9.1ms preprocess, 1089.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1067.5ms
# Speed: 0.0ms preprocess, 1067.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 999.0ms
# Speed: 2.3ms preprocess, 999.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1005.6ms
# Speed: 0.0ms preprocess, 1005.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1116.0ms
# Speed: 0.0ms preprocess, 1116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1332.4ms
# Speed: 3.4ms preprocess, 1332.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1058.4ms
# Speed: 3.2ms preprocess, 1058.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1106.1ms
# Speed: 0.0ms preprocess, 1106.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1091.8ms
# Speed: 2.0ms preprocess, 1091.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1026.3ms
# Speed: 2.9ms preprocess, 1026.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1412.0ms
# Speed: 2.5ms preprocess, 1412.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1552.8ms
# Speed: 8.7ms preprocess, 1552.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1651.6ms
# Speed: 15.1ms preprocess, 1651.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1648.9ms
# Speed: 1.5ms preprocess, 1648.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1513.8ms
# Speed: 6.4ms preprocess, 1513.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1537.2ms
# Speed: 3.0ms preprocess, 1537.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1552.4ms
# Speed: 3.7ms preprocess, 1552.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1929.5ms
# Speed: 4.0ms preprocess, 1929.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1567.5ms
# Speed: 4.0ms preprocess, 1567.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1614.7ms
# Speed: 3.1ms preprocess, 1614.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1049.7ms
# Speed: 0.0ms preprocess, 1049.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1011.8ms
# Speed: 1.8ms preprocess, 1011.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1016.7ms
# Speed: 16.6ms preprocess, 1016.7ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 985.4ms
# Speed: 0.0ms preprocess, 985.4ms inference, 12.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1042.6ms
# Speed: 0.0ms preprocess, 1042.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1045.3ms
# Speed: 2.7ms preprocess, 1045.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1033.8ms
# Speed: 7.9ms preprocess, 1033.8ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1460.5ms
# Speed: 2.9ms preprocess, 1460.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1581.8ms
# Speed: 0.0ms preprocess, 1581.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1658.2ms
# Speed: 0.0ms preprocess, 1658.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1840.2ms
# Speed: 4.1ms preprocess, 1840.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1744.9ms
# Speed: 5.0ms preprocess, 1744.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1027.9ms
# Speed: 0.0ms preprocess, 1027.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1021.5ms
# Speed: 2.1ms preprocess, 1021.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1016.2ms
# Speed: 0.0ms preprocess, 1016.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1059.9ms
# Speed: 2.0ms preprocess, 1059.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1000.8ms
# Speed: 0.0ms preprocess, 1000.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1075.1ms
# Speed: 3.2ms preprocess, 1075.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1038.1ms
# Speed: 17.1ms preprocess, 1038.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1065.4ms
# Speed: 2.5ms preprocess, 1065.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1600.9ms
# Speed: 17.6ms preprocess, 1600.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1667.5ms
# Speed: 16.2ms preprocess, 1667.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1636.1ms
# Speed: 5.3ms preprocess, 1636.1ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1771.7ms
# Speed: 6.0ms preprocess, 1771.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1709.0ms
# Speed: 0.0ms preprocess, 1709.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1805.2ms
# Speed: 4.7ms preprocess, 1805.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1451.4ms
# Speed: 3.1ms preprocess, 1451.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1483.4ms
# Speed: 0.0ms preprocess, 1483.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1466.4ms
# Speed: 15.4ms preprocess, 1466.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1534.0ms
# Speed: 0.0ms preprocess, 1534.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1551.2ms
# Speed: 3.5ms preprocess, 1551.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1520.1ms
# Speed: 3.6ms preprocess, 1520.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1848.5ms
# Speed: 2.2ms preprocess, 1848.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1680.6ms
# Speed: 3.6ms preprocess, 1680.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1736.2ms
# Speed: 0.0ms preprocess, 1736.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1688.4ms
# Speed: 10.1ms preprocess, 1688.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1082.2ms
# Speed: 0.3ms preprocess, 1082.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1011.1ms
# Speed: 2.0ms preprocess, 1011.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1056.2ms
# Speed: 0.0ms preprocess, 1056.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1039.7ms
# Speed: 1.0ms preprocess, 1039.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 979.6ms
# Speed: 3.2ms preprocess, 979.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1005.4ms
# Speed: 1.9ms preprocess, 1005.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1000.1ms
# Speed: 0.0ms preprocess, 1000.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1023.1ms
# Speed: 14.3ms preprocess, 1023.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 945.5ms
# Speed: 0.0ms preprocess, 945.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1578.2ms
# Speed: 0.0ms preprocess, 1578.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1759.0ms
# Speed: 0.0ms preprocess, 1759.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1659.1ms
# Speed: 1.7ms preprocess, 1659.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1693.9ms
# Speed: 0.0ms preprocess, 1693.9ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1510.4ms
# Speed: 5.1ms preprocess, 1510.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1566.7ms
# Speed: 0.0ms preprocess, 1566.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1780.0ms
# Speed: 1.5ms preprocess, 1780.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1773.4ms
# Speed: 6.6ms preprocess, 1773.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1699.6ms
# Speed: 0.0ms preprocess, 1699.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1040.5ms
# Speed: 3.7ms preprocess, 1040.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1021.1ms
# Speed: 4.8ms preprocess, 1021.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1037.3ms
# Speed: 1.3ms preprocess, 1037.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1058.9ms
# Speed: 0.0ms preprocess, 1058.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 982.6ms
# Speed: 3.3ms preprocess, 982.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1050.4ms
# Speed: 0.5ms preprocess, 1050.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1052.4ms
# Speed: 2.3ms preprocess, 1052.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1076.0ms
# Speed: 1.5ms preprocess, 1076.0ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1312.7ms
# Speed: 3.1ms preprocess, 1312.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1714.0ms
# Speed: 5.0ms preprocess, 1714.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1649.5ms
# Speed: 3.2ms preprocess, 1649.5ms inference, 13.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1792.5ms
# Speed: 6.5ms preprocess, 1792.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1010.2ms
# Speed: 1.9ms preprocess, 1010.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 940.4ms
# Speed: 0.0ms preprocess, 940.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 979.3ms
# Speed: 2.1ms preprocess, 979.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 936.6ms
# Speed: 2.0ms preprocess, 936.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 948.4ms
# Speed: 1.5ms preprocess, 948.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1045.0ms
# Speed: 3.0ms preprocess, 1045.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1049.7ms
# Speed: 0.0ms preprocess, 1049.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1246.4ms
# Speed: 2.1ms preprocess, 1246.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1612.3ms
# Speed: 4.4ms preprocess, 1612.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1742.2ms
# Speed: 7.2ms preprocess, 1742.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1743.9ms
# Speed: 0.0ms preprocess, 1743.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1702.1ms
# Speed: 4.5ms preprocess, 1702.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1061.2ms
# Speed: 4.2ms preprocess, 1061.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1044.5ms
# Speed: 2.0ms preprocess, 1044.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1013.1ms
# Speed: 2.9ms preprocess, 1013.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1013.8ms
# Speed: 0.0ms preprocess, 1013.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1046.0ms
# Speed: 0.0ms preprocess, 1046.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1084.3ms
# Speed: 9.2ms preprocess, 1084.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1006.5ms
# Speed: 13.8ms preprocess, 1006.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1077.4ms
# Speed: 4.1ms preprocess, 1077.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1243.1ms
# Speed: 1.2ms preprocess, 1243.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1802.2ms
# Speed: 3.3ms preprocess, 1802.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1822.0ms
# Speed: 6.4ms preprocess, 1822.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1827.1ms
# Speed: 3.4ms preprocess, 1827.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1120.9ms
# Speed: 4.1ms preprocess, 1120.9ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1736.2ms
# Speed: 10.1ms preprocess, 1736.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1900.4ms
# Speed: 7.0ms preprocess, 1900.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1719.5ms
# Speed: 4.2ms preprocess, 1719.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1842.6ms
# Speed: 5.0ms preprocess, 1842.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 2038.8ms
# Speed: 0.0ms preprocess, 2038.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1656.7ms
# Speed: 17.9ms preprocess, 1656.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1699.8ms
# Speed: 7.4ms preprocess, 1699.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1597.3ms
# Speed: 3.8ms preprocess, 1597.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1674.0ms
# Speed: 16.2ms preprocess, 1674.0ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1702.5ms
# Speed: 4.1ms preprocess, 1702.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1770.9ms
# Speed: 4.1ms preprocess, 1770.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1687.0ms
# Speed: 0.0ms preprocess, 1687.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1871.1ms
# Speed: 6.5ms preprocess, 1871.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1699.1ms
# Speed: 11.2ms preprocess, 1699.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1507.6ms
# Speed: 1.4ms preprocess, 1507.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1469.2ms
# Speed: 0.5ms preprocess, 1469.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1670.4ms
# Speed: 3.0ms preprocess, 1670.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1690.5ms
# Speed: 15.6ms preprocess, 1690.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1644.4ms
# Speed: 16.5ms preprocess, 1644.4ms inference, 16.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1717.4ms
# Speed: 0.0ms preprocess, 1717.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1100.3ms
# Speed: 3.1ms preprocess, 1100.3ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1469.9ms
# Speed: 0.0ms preprocess, 1469.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1517.3ms
# Speed: 1.5ms preprocess, 1517.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1476.5ms
# Speed: 3.0ms preprocess, 1476.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1341.7ms
# Speed: 0.7ms preprocess, 1341.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1378.4ms
# Speed: 0.0ms preprocess, 1378.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1411.2ms
# Speed: 0.0ms preprocess, 1411.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Alive, 1583.9ms
# Speed: 16.6ms preprocess, 1583.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1477.4ms
# Speed: 0.0ms preprocess, 1477.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1726.8ms
# Speed: 0.0ms preprocess, 1726.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1700.5ms
# Speed: 0.0ms preprocess, 1700.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1517.2ms
# ...
#
# 0: 640x384 (no detections), 972.1ms
# Speed: 3.0ms preprocess, 972.1ms inference, 14.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1037.2ms
# Speed: 15.5ms preprocess, 1037.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1142.3ms
# Speed: 13.3ms preprocess, 1142.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1028.3ms
# Speed: 15.4ms preprocess, 1028.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1110.8ms
# Speed: 0.0ms preprocess, 1110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1019.2ms
# Speed: 3.0ms preprocess, 1019.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1071.2ms
# Speed: 3.3ms preprocess, 1071.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1000.8ms
# Speed: 0.0ms preprocess, 1000.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1075.2ms
# Speed: 1.6ms preprocess, 1075.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1094.2ms
# Speed: 3.5ms preprocess, 1094.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Deads, 1009.7ms
# Speed: 2.3ms preprocess, 1009.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1053.4ms
# Speed: 0.0ms preprocess, 1053.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1025.2ms
# Speed: 3.5ms preprocess, 1025.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Deads, 979.8ms
# Speed: 0.0ms preprocess, 979.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1098.1ms
# Speed: 0.0ms preprocess, 1098.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1096.7ms
# Speed: 0.0ms preprocess, 1096.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1059.8ms
# Speed: 8.6ms preprocess, 1059.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1061.9ms
# Speed: 0.0ms preprocess, 1061.9ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1049.8ms
# Speed: 47.5ms preprocess, 1049.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 935.2ms
# Speed: 15.7ms preprocess, 935.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 929.5ms
# Speed: 0.0ms preprocess, 929.5ms inference, 14.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 980.9ms
# Speed: 3.0ms preprocess, 980.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1085.5ms
# Speed: 14.4ms preprocess, 1085.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1077.0ms
# Speed: 3.0ms preprocess, 1077.0ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1027.9ms
# Speed: 2.5ms preprocess, 1027.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1010.6ms
# Speed: 32.0ms preprocess, 1010.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1058.7ms
# Speed: 0.0ms preprocess, 1058.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1095.8ms
# Speed: 17.5ms preprocess, 1095.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1063.0ms
# Speed: 0.0ms preprocess, 1063.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1056.7ms
# Speed: 0.0ms preprocess, 1056.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1114.3ms
# Speed: 3.6ms preprocess, 1114.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1014.3ms
# Speed: 4.5ms preprocess, 1014.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1153.1ms
# Speed: 6.3ms preprocess, 1153.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1074.7ms
# Speed: 2.0ms preprocess, 1074.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1136.6ms
# Speed: 2.2ms preprocess, 1136.6ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1015.2ms
# Speed: 0.0ms preprocess, 1015.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1110.7ms
# Speed: 0.0ms preprocess, 1110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1052.2ms
# Speed: 0.0ms preprocess, 1052.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 997.4ms
# Speed: 3.0ms preprocess, 997.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1069.2ms
# Speed: 0.0ms preprocess, 1069.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 983.5ms
# Speed: 0.7ms preprocess, 983.5ms inference, 15.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1099.4ms
# Speed: 6.6ms preprocess, 1099.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1145.5ms
# Speed: 0.0ms preprocess, 1145.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1062.5ms
# Speed: 0.0ms preprocess, 1062.5ms inference, 11.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1162.4ms
# Speed: 0.0ms preprocess, 1162.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1167.5ms
# Speed: 0.0ms preprocess, 1167.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1035.5ms
# Speed: 1.6ms preprocess, 1035.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1017.0ms
# Speed: 16.2ms preprocess, 1017.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1072.0ms
# Speed: 0.0ms preprocess, 1072.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1028.9ms
# Speed: 2.0ms preprocess, 1028.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1008.6ms
# Speed: 15.7ms preprocess, 1008.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1029.0ms
# Speed: 0.0ms preprocess, 1029.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 999.2ms
# Speed: 0.0ms preprocess, 999.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1121.8ms
# Speed: 3.6ms preprocess, 1121.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1074.6ms
# Speed: 5.0ms preprocess, 1074.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1097.4ms
# Speed: 10.3ms preprocess, 1097.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1086.7ms
# Speed: 3.6ms preprocess, 1086.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1150.5ms
# Speed: 1.5ms preprocess, 1150.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1087.1ms
# Speed: 0.0ms preprocess, 1087.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1150.1ms
# Speed: 12.3ms preprocess, 1150.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1024.3ms
# Speed: 4.7ms preprocess, 1024.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1071.8ms
# Speed: 18.3ms preprocess, 1071.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1133.1ms
# Speed: 0.0ms preprocess, 1133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1140.6ms
# Speed: 0.0ms preprocess, 1140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1076.6ms
# Speed: 0.0ms preprocess, 1076.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1013.7ms
# Speed: 0.0ms preprocess, 1013.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1106.3ms
# Speed: 0.0ms preprocess, 1106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1077.6ms
# Speed: 0.0ms preprocess, 1077.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1112.0ms
# Speed: 0.0ms preprocess, 1112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1124.1ms
# Speed: 0.0ms preprocess, 1124.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1033.8ms
# Speed: 0.0ms preprocess, 1033.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1046.1ms
# Speed: 20.7ms preprocess, 1046.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1112.1ms
# Speed: 0.0ms preprocess, 1112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1012.6ms
# Speed: 3.0ms preprocess, 1012.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1053.2ms
# Speed: 0.0ms preprocess, 1053.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1064.5ms
# Speed: 0.0ms preprocess, 1064.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 946.4ms
# Speed: 2.2ms preprocess, 946.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1000.8ms
# Speed: 0.0ms preprocess, 1000.8ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1011.0ms
# Speed: 0.0ms preprocess, 1011.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 983.6ms
# Speed: 0.0ms preprocess, 983.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1044.4ms
# Speed: 1.9ms preprocess, 1044.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1129.7ms
# Speed: 0.0ms preprocess, 1129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1017.2ms
# Speed: 0.0ms preprocess, 1017.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1111.2ms
# Speed: 29.3ms preprocess, 1111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1171.4ms
# Speed: 0.0ms preprocess, 1171.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1051.6ms
# Speed: 16.7ms preprocess, 1051.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1152.6ms
# Speed: 0.0ms preprocess, 1152.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1085.2ms
# Speed: 1.9ms preprocess, 1085.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1072.7ms
# Speed: 0.0ms preprocess, 1072.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1003.0ms
# Speed: 2.2ms preprocess, 1003.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1131.2ms
# Speed: 0.5ms preprocess, 1131.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1000.4ms
# Speed: 0.0ms preprocess, 1000.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1051.3ms
# Speed: 3.1ms preprocess, 1051.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1084.1ms
# Speed: 0.0ms preprocess, 1084.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 967.4ms
# Speed: 3.3ms preprocess, 967.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 952.8ms
# Speed: 3.3ms preprocess, 952.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1000.2ms
# Speed: 0.0ms preprocess, 1000.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1036.2ms
# Speed: 0.0ms preprocess, 1036.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1067.7ms
# Speed: 1.4ms preprocess, 1067.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1103.2ms
# Speed: 0.0ms preprocess, 1103.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1152.9ms
# Speed: 0.0ms preprocess, 1152.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1160.3ms
# Speed: 6.5ms preprocess, 1160.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1124.0ms
# Speed: 3.7ms preprocess, 1124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1047.2ms
# Speed: 0.0ms preprocess, 1047.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1051.3ms
# Speed: 0.0ms preprocess, 1051.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1085.1ms
# Speed: 0.0ms preprocess, 1085.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1021.6ms
# Speed: 0.0ms preprocess, 1021.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1013.4ms
# Speed: 16.3ms preprocess, 1013.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1066.4ms
# Speed: 3.0ms preprocess, 1066.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 975.7ms
# Speed: 0.0ms preprocess, 975.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1050.8ms
# Speed: 0.0ms preprocess, 1050.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1071.1ms
# Speed: 0.0ms preprocess, 1071.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1029.5ms
# Speed: 4.1ms preprocess, 1029.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1165.1ms
# Speed: 16.3ms preprocess, 1165.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1145.1ms
# Speed: 0.0ms preprocess, 1145.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead, 1053.7ms
# Speed: 13.9ms preprocess, 1053.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 1149.2ms
# Speed: 6.5ms preprocess, 1149.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 999.9ms
# Speed: 0.0ms preprocess, 999.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
# El frame del video está vacío o el procesamiento del video se ha completado correctamente.

# %%
cap.release()
video_writer.release()
cv2.destroyAllWindows()

# %%
import pandas as pd
import openpyxl

# Datos de counter_dead.counting_list
data_dead = {'id': counter_dead.counting_list, 'class': 'dead'}
df_dead = pd.DataFrame(data_dead)

# Datos de counter_alive.counting_list
data_alive = {'id': counter_alive.counting_list, 'class': 'alive'}
df_alive = pd.DataFrame(data_alive)

# Unir ambos dataframes
df_combined = pd.concat([df_dead, df_alive], ignore_index=True)

# Ordenar por ID
df_combined = df_combined.sort_values(by='id')

# Guardar en un archivo Excel
excel_filename = 'combined_counts.xlsx'
df_combined.to_excel(excel_filename, index=False)

# %%
#!pip install openpyxl

# %%
#!pip install shapely
# !conda activate myenv && pip install shapely

# %%
import shapely

print(shapely.__file__)

# %%
# !conda activate myenv && pip install lapx

# %%
#tracker1
print(dir(counts_all))
# Out:
# ['T', '__abs__', '__add__', '__and__', '__array__', '__array_finalize__', '__array_function__', '__array_interface__', '__array_prepare__', '__array_priority__', '__array_struct__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__class_getitem__', '__complex__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__divmod__', '__dlpack__', '__dlpack_device__', '__doc__', '__eq__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__ilshift__', '__imatmul__', '__imod__', '__imul__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__irshift__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lshift__', '__lt__', '__matmul__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__xor__', 'all', 'any', 'argmax', 'argmin', 'argpartition', 'argsort', 'astype', 'base', 'byteswap', 'choose', 'clip', 'compress', 'conj', 'conjugate', 'copy', 'ctypes', 'cumprod', 'cumsum', 'data', 'diagonal', 'dot', 'dtype', 'dump', 'dumps', 'fill', 'flags', 'flat', 'flatten', 'getfield', 'imag', 'item', 'itemset', 'itemsize', 'max', 'mean', 'min', 'nbytes', 'ndim', 'newbyteorder', 'nonzero', 'partition', 'prod', 'ptp', 'put', 'ravel', 'real', 'repeat', 'reshape', 'resize', 'round', 'searchsorted', 'setfield', 'setflags', 'shape', 'size', 'sort', 'squeeze', 'std', 'strides', 'sum', 'swapaxes', 'take', 'tobytes', 'tofile', 'tolist', 'tostring', 'trace', 'transpose', 'var', 'view']

# %%
# Objeto counts_dead
print("Información de cada elemento de la lista:")
for atributo in dir(counter_all):
    # Utiliza getattr() para obtener el valor del atributo
    valor_atributo = getattr(counter_all, atributo)
    # Imprime el nombre del atributo y su valor
    print(f"{atributo}: {valor_atributo}")
# Out:
# Información de cada elemento de la lista:
# __class__: <class 'ultralytics.solutions.object_counter.ObjectCounter'>
# __delattr__: <method-wrapper '__delattr__' of ObjectCounter object at 0x0000022284E42B90>
# __dict__: {'is_drawing': False, 'selected_point': None, 'reg_pts': [(432.0, 0), (432.0, 1920), (540.0, 1920), (540.0, 0)], 'line_dist_thresh': 15, 'counting_region': <POLYGON ((432 0, 432 1920, 540 1920, 540 0, 432 0))>, 'region_color': (255, 0, 255), 'region_thickness': 5, 'im0': array([[[252, 250, 235],
#         [252, 250, 235],
#         [253, 251, 236],
#         ...,
#         [206, 178, 159],
#         [206, 178, 159],
#         [206, 178, 159]],
#
#        [[252, 250, 235],
#         [252, 250, 235],
#         [253, 251, 236],
#         ...,
#         [204, 176, 157],
#         [204, 176, 157],
#         [204, 176, 157]],
#
#        [[252, 250, 235],
#         [252, 250, 235],
#         [253, 251, 236],
#         ...,
#         [205, 177, 158],
#         [205, 177, 158],
#         [205, 177, 158]],
#
#        ...,
#
#        [[ 47,  44,  51],
#         [ 47,  44,  51],
#         [ 47,  44,  51],
#         ...,
#         [ 66,  61,  69],
#         [ 66,  61,  69],
#         [ 66,  61,  69]],
#
#        [[ 47,  44,  51],
#         [ 47,  44,  51],
#         [ 47,  44,  51],
#         ...,
#         [ 66,  61,  69],
#         [ 66,  61,  69],
#         [ 66,  61,  69]],
#
#        [[ 47,  44,  51],
#         [ 47,  44,  51],
#         [ 47,  44,  51],
#         ...,
#         [ 66,  61,  69],
#         [ 66,  61,  69],
#         [ 66,  61,  69]]], dtype=uint8), 'tf': 2, 'view_img': False, 'view_in_counts': False, 'view_out_counts': False, 'names': {0: 'Dead', 1: 'Alive'}, 'annotator': <ultralytics.utils.plotting.Annotator object at 0x00000222936CB910>, 'in_counts': 0, 'out_counts': 4, 'counting_list': [4, 8, 11, 17], 'count_txt_thickness': 2, 'count_txt_color': (0, 0, 0), 'count_color': (255, 255, 255), 'track_history': defaultdict(<class 'list'>, {4: [(936.9225463867188, 958.21484375), (921.8114013671875, 955.8579711914062), (908.01611328125, 942.8403930664062), (889.32470703125, 959.5477905273438), (887.4158935546875, 955.8292236328125), (885.300048828125, 961.3876953125), (859.684814453125, 958.5404052734375), (860.0623779296875, 967.8726806640625), (844.9864501953125, 988.7839965820312), (819.6116943359375, 984.1397705078125), (736.3682861328125, 998.7425537109375), (475.3539123535156, 1092.408447265625), (444.08831787109375, 1111.28369140625)], 5: [(696.5491943359375, 987.9586181640625), (679.0677490234375, 978.6378784179688), (671.43115234375, 971.95068359375)], 8: [(682.5419921875, 1138.909912109375), (583.9580688476562, 1240.4130859375), (559.3521728515625, 1251.90283203125), (482.4537353515625, 1248.3095703125), (443.8793029785156, 1222.009521484375), (381.312255859375, 1202.188232421875)], 11: [(683.991455078125, 1267.8154296875), (494.6383056640625, 1210.91796875), (474.784912109375, 1258.1226806640625)], 17: [(710.64111328125, 1239.4375), (511.58447265625, 1242.090087890625), (490.63006591796875, 1255.4967041015625)]}), 'track_thickness': 2, 'draw_tracks': True, 'track_color': (0, 255, 0), 'env_check': True, 'counter_variable': 0}
# __dir__: <built-in method __dir__ of ObjectCounter object at 0x0000022284E42B90>
# __doc__: A class to manage the counting of objects in a real-time video stream based on their tracks.
# __eq__: <method-wrapper '__eq__' of ObjectCounter object at 0x0000022284E42B90>
# __format__: <built-in method __format__ of ObjectCounter object at 0x0000022284E42B90>
# __ge__: <method-wrapper '__ge__' of ObjectCounter object at 0x0000022284E42B90>
# __getattribute__: <method-wrapper '__getattribute__' of ObjectCounter object at 0x0000022284E42B90>
# __getstate__: <built-in method __getstate__ of ObjectCounter object at 0x0000022284E42B90>
# __gt__: <method-wrapper '__gt__' of ObjectCounter object at 0x0000022284E42B90>
# __hash__: <method-wrapper '__hash__' of ObjectCounter object at 0x0000022284E42B90>
# __init__: <bound method ObjectCounter.__init__ of <ultralytics.solutions.object_counter.ObjectCounter object at 0x0000022284E42B90>>
# __init_subclass__: <built-in method __init_subclass__ of type object at 0x00000222FC1A10E0>
# __le__: <method-wrapper '__le__' of ObjectCounter object at 0x0000022284E42B90>
# __lt__: <method-wrapper '__lt__' of ObjectCounter object at 0x0000022284E42B90>
# __module__: ultralytics.solutions.object_counter
# __ne__: <method-wrapper '__ne__' of ObjectCounter object at 0x0000022284E42B90>
# __new__: <built-in method __new__ of type object at 0x00007FFF4B31C330>
# __reduce__: <built-in method __reduce__ of ObjectCounter object at 0x0000022284E42B90>
# __reduce_ex__: <built-in method __reduce_ex__ of ObjectCounter object at 0x0000022284E42B90>
# __repr__: <method-wrapper '__repr__' of ObjectCounter object at 0x0000022284E42B90>
# __setattr__: <method-wrapper '__setattr__' of ObjectCounter object at 0x0000022284E42B90>
# __sizeof__: <built-in method __sizeof__ of ObjectCounter object at 0x0000022284E42B90>
# __str__: <method-wrapper '__str__' of ObjectCounter object at 0x0000022284E42B90>
# __subclasshook__: <built-in method __subclasshook__ of type object at 0x00000222FC1A10E0>
# __weakref__: None
# annotator: <ultralytics.utils.plotting.Annotator object at 0x00000222936CB910>
# count_color: (255, 255, 255)
# count_txt_color: (0, 0, 0)
# count_txt_thickness: 2
# counter_variable: 0
# counting_list: [4, 8, 11, 17]
# counting_region: POLYGON ((432 0, 432 1920, 540 1920, 540 0, 432 0))
# display_frames: <bound method ObjectCounter.display_frames of <ultralytics.solutions.object_counter.ObjectCounter object at 0x0000022284E42B90>>
# draw_tracks: True
# env_check: True
# extract_and_process_tracks: <bound method ObjectCounter.extract_and_process_tracks of <ultralytics.solutions.object_counter.ObjectCounter object at 0x0000022284E42B90>>
# im0: [[[252 250 235]
#   [252 250 235]
#   [253 251 236]
#   ...
#   [206 178 159]
#   [206 178 159]
#   [206 178 159]]
#
#  [[252 250 235]
#   [252 250 235]
#   [253 251 236]
#   ...
#   [204 176 157]
#   [204 176 157]
#   [204 176 157]]
#
#  [[252 250 235]
#   [252 250 235]
#   [253 251 236]
#   ...
#   [205 177 158]
#   [205 177 158]
#   [205 177 158]]
#
#  ...
#
#  [[ 47  44  51]
#   [ 47  44  51]
#   [ 47  44  51]
#   ...
#   [ 66  61  69]
#   [ 66  61  69]
#   [ 66  61  69]]
#
#  [[ 47  44  51]
#   [ 47  44  51]
#   [ 47  44  51]
#   ...
#   [ 66  61  69]
#   [ 66  61  69]
#   [ 66  61  69]]
#
#  [[ 47  44  51]
#   [ 47  44  51]
#   [ 47  44  51]
#   ...
#   [ 66  61  69]
#   [ 66  61  69]
#   [ 66  61  69]]]
# in_counts: 0
# is_drawing: False
# line_dist_thresh: 15
# mouse_event_for_region: <bound method ObjectCounter.mouse_event_for_region of <ultralytics.solutions.object_counter.ObjectCounter object at 0x0000022284E42B90>>
# names: {0: 'Dead', 1: 'Alive'}
# out_counts: 4
# reg_pts: [(432.0, 0), (432.0, 1920), (540.0, 1920), (540.0, 0)]
# region_color: (255, 0, 255)
# region_thickness: 5
# selected_point: None
# set_args: <bound method ObjectCounter.set_args of <ultralytics.solutions.object_counter.ObjectCounter object at 0x0000022284E42B90>>
# start_counting: <bound method ObjectCounter.start_counting of <ultralytics.solutions.object_counter.ObjectCounter object at 0x0000022284E42B90>>
# tf: 2
# track_color: (0, 255, 0)
# track_history: defaultdict(<class 'list'>, {4: [(936.9225463867188, 958.21484375), (921.8114013671875, 955.8579711914062), (908.01611328125, 942.8403930664062), (889.32470703125, 959.5477905273438), (887.4158935546875, 955.8292236328125), (885.300048828125, 961.3876953125), (859.684814453125, 958.5404052734375), (860.0623779296875, 967.8726806640625), (844.9864501953125, 988.7839965820312), (819.6116943359375, 984.1397705078125), (736.3682861328125, 998.7425537109375), (475.3539123535156, 1092.408447265625), (444.08831787109375, 1111.28369140625)], 5: [(696.5491943359375, 987.9586181640625), (679.0677490234375, 978.6378784179688), (671.43115234375, 971.95068359375)], 8: [(682.5419921875, 1138.909912109375), (583.9580688476562, 1240.4130859375), (559.3521728515625, 1251.90283203125), (482.4537353515625, 1248.3095703125), (443.8793029785156, 1222.009521484375), (381.312255859375, 1202.188232421875)], 11: [(683.991455078125, 1267.8154296875), (494.6383056640625, 1210.91796875), (474.784912109375, 1258.1226806640625)], 17: [(710.64111328125, 1239.4375), (511.58447265625, 1242.090087890625), (490.63006591796875, 1255.4967041015625)]})
# track_thickness: 2
# view_img: False
# view_in_counts: False
# view_out_counts: False

# %%
# Acceder a los conteos
in_count = counter_dead.in_counts
in_count

# %%
out_count = counter_dead.out_counts
out_count

# %%
clases_detectadas = counter_dead.track_history

# Obtener solo los ID de cada objeto detectado
ids_detectados = list(clases_detectadas.keys())

# Imprimir los ID de los objetos detectados
print(ids_detectados)
# Out:
# [1, 2, 3]

# %%
counter_dead.counting_list
# Out:
# [1, 2, 3]

# %%
counter_alive.counting_list
# Out:
# [5, 4, 8, 11, 17]

# %% [markdown]
# ## Guardar video en dimensiones personalizadas

# %%
# Nombre del archivo de video de entrada
video_path = "8.mp4"

# Nombre del archivo de video de salida (formato MP4)
output_path = "output.mp4"

# Inicializar el lector de video
cap = cv2.VideoCapture(video_path)

# Obtener las propiedades del video (ancho, alto, fps)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Inicializar el escritor de video
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Resize the frame to a smaller resolution (optional)
        frame = cv2.resize(frame, (600, 800))  # Adjust the new_width and new_height

        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Write the annotated frame to the output video
        out.write(annotated_frame)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Reduce the delay for higher FPS
        # cv2.waitKey(1)  # Set a delay for approximately 60 FPS

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break 

# Liberar recursos
cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Guardar video en dimensiones reales

# %%
# Inicializar el lector de video
cap = cv2.VideoCapture(video_path)

# Obtener las propiedades del video (ancho, alto, fps)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# %%
width

# %%
height

# %%
# Inicializar el lector de video
cap = cv2.VideoCapture(video_path)

# Obtener las propiedades del video (ancho, alto, fps)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Inicializar el escritor de video
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Escribir el frame procesado en el video de salida
        out.write(annotated_frame)

    else:
        # Break the loop if the end of the video is reached
        break 

# Liberar recursos
cap.release()
out.release()

print(f"Video de salida guardado en: {output_path}")

# %% [markdown]
# ## Inferencias en tiempo real

# %%
# Establecer la dirección IP y el puerto proporcionados por la aplicación "IP Webcam"
ip_address = "http://10.4.41.24:8080"  # Ruta base proporcionada por la aplicación

# URL completa para acceder al video en vivo
video_url = f"{ip_address}/video"

# Obtener la resolución de tu pantalla
screen_width = 1920  # Reemplaza con la resolución de tu pantalla
screen_height = 1080  # Reemplaza con la resolución de tu pantalla

# Crear un objeto VideoCapture para acceder al video de la cámara del teléfono
cap = cv2.VideoCapture(video_url)

while True:
    # Capturar un fotograma de la cámara del teléfono
    ret, frame = cap.read()

    if success:
        # Resize the frame to a smaller resolution (optional)
        frame = cv2.resize(frame, (screen_width, screen_height))  # Adjust the new_width and new_height

        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Reduce the delay for higher FPS
        # cv2.waitKey(1)  # Set a delay for approximately 60 FPS

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# %%
# Liberar la cámara y cerrar las ventanas
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Conteo, Tracking, Registro en tiempo real

# %%
import cv2
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import csv
import pandas as pd
import openpyxl
import threading

model = YOLO("G:/Mi unidad/Python/Proyecto-vigor-defoliacion/runs/detect/train8/weights/best.pt/")

excel_filename = 'combined_counts_test.xlsx'

# Establecer la dirección IP y el puerto proporcionados por la aplicación "IP Webcam"
ip_address = "https://172.20.10.12:8080"  # Ruta base proporcionada por la aplicación

# URL completa para acceder al video en vivo
#video_url = f"{ip_address}/video"
video_url = 0

cap = cv2.VideoCapture(video_url)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Porcentaje de reducción de tamaño de la ventana
reduction_percentage = 100

# Define region points in a vertical orientation
region_points = [(w*0.40, 0), (w*0.40, h), 
                 (w*0.50, h), (w*0.50, 0)]  # Ajusta las coordenadas según tus preferencias

classes_to_count = [0, 1]

# Clases a contar (Dead y Alive)
classes_to_count_dead = [0]  # Reemplaza con el índice correcto de la clase "Dead"
classes_to_count_alive = [1]  # Reemplaza con el índice correcto de la clase "Alive"

# Video writer
video_writer = cv2.VideoWriter("object_counting_multiclass_test2.avi",
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       fps,
                       (w, h))

# Init Object Counters for each class
counter_dead = object_counter.ObjectCounter()
counter_dead.counter_variable = 0
counter_dead.set_args(view_img=False,
                      view_in_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia adentro
                      view_out_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia afuera
                      reg_pts=region_points,
                      classes_names=model.model.names,
                      draw_tracks=True)

counter_alive = object_counter.ObjectCounter()
counter_alive.counter_variable = 0
counter_alive.set_args(view_img=False,
                       view_in_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia adentro
                       view_out_counts=False,  # Configura esto a False para no mostrar etiquetas de conteo hacia afuera
                       reg_pts=region_points,
                       classes_names=model.model.names,
                       draw_tracks=True)

df_combined = pd.DataFrame(columns=['id', 'class'])  # DataFrame compartido entre hilos

def procesar_video():
    global df_combined

    while cap.isOpened():
        success, im0 = cap.read()
        if not success:
            print("El frame del video está vacío o el procesamiento del video se ha completado correctamente.")
            break

        counters_by_class = {"Dead": counter_dead, "Alive": counter_alive}
        
        tracks_dead = model.track(im0, persist=True, show=False, classes=classes_to_count_dead)
        counts_dead = counters_by_class["Dead"].start_counting(im0, tracks_dead)

        tracks_alive = model.track(im0, persist=True, show=False, classes=classes_to_count_alive)
        counts_alive = counters_by_class["Alive"].start_counting(im0, tracks_alive)

        # Dead Count
        text_dead = f'Dead: {counter_dead.out_counts}'
        font_dead = cv2.FONT_HERSHEY_SIMPLEX
        font_scale_dead = 2
        font_thickness_dead = 4
        font_color_dead = (0, 0, 255)
        background_color_dead = (0, 0, 0)

        # Get the size of the text
        (text_width_dead, text_height_dead), _ = cv2.getTextSize(text_dead, font_dead, font_scale_dead, font_thickness_dead)

        # Set the position for the text
        text_position_dead = (10, 60)

        # Create a black background for the text
        background_rect_dead = (text_position_dead[0], text_position_dead[1] - text_height_dead, text_width_dead, text_height_dead)
        cv2.rectangle(im0, background_rect_dead, background_color_dead, thickness=cv2.FILLED)

        # Put the text on the image
        cv2.putText(im0, text_dead, text_position_dead, font_dead, font_scale_dead, font_color_dead, font_thickness_dead, cv2.LINE_AA)

        # Alive Count
        text_alive = f'Alive: {counter_alive.out_counts}'
        font_alive = cv2.FONT_HERSHEY_SIMPLEX
        font_scale_alive = 2
        font_thickness_alive = 4
        font_color_alive = (0, 255, 0)
        background_color_alive = (0, 0, 0)

        # Get the size of the text
        (text_width_alive, text_height_alive), _ = cv2.getTextSize(text_alive, font_alive, font_scale_alive, font_thickness_alive)

        # Set the position for the text
        text_position_alive = (10, 110)

        # Create a black background for the text
        background_rect_alive = (text_position_alive[0], text_position_alive[1] - text_height_alive, text_width_alive, text_height_alive)
        cv2.rectangle(im0, background_rect_alive, background_color_alive, thickness=cv2.FILLED)

        # Put the text on the image
        cv2.putText(im0, text_alive, text_position_alive, font_alive, font_scale_alive, font_color_alive, font_thickness_alive, cv2.LINE_AA)

        data_dead = {'id': counter_dead.counting_list, 'class': 'dead'}
        df_dead = pd.DataFrame(data_dead)

        data_alive = {'id': counter_alive.counting_list, 'class': 'alive'}
        df_alive = pd.DataFrame(data_alive)

        df_combined = pd.concat([df_dead, df_alive], ignore_index=True)
        df_combined = df_combined.sort_values(by='id')

        df_combined.to_excel(excel_filename, index=False)

        small_frame = cv2.resize(im0, (int(w * reduction_percentage / 100), int(h * reduction_percentage / 100)))
        video_writer.write(im0)

        cv2.imshow("Object Counting", small_frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

# Inicia el hilo para procesar el video
video_thread = threading.Thread(target=procesar_video)
video_thread.start()

# Espera a que el hilo de video termine antes de cerrar la aplicación
video_thread.join()

# %%
cap.release()
video_writer.release()
cv2.destroyAllWindows()

# %%
from time import time

# %%
# Establecer la dirección IP y el puerto proporcionados por la aplicación "IP Webcam"
ip_address = "http://10.4.41.24:8080"  # Ruta base proporcionada por la aplicación

# URL completa para acceder al video en vivo
video_url = f"{ip_address}/video"

# Crear un objeto VideoCapture para acceder al video de la cámara del teléfono
cap = cv2.VideoCapture(video_url)

# Obtener la resolución del fotograma de la cámara
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))

# Inicializar el tiempo de referencia para el control de velocidad
start_time = time()

# Velocidad objetivo en FPS
target_fps = 10  # Puedes ajustar esto a la velocidad deseada

# %%
while True:
    # Capturar un fotograma de la cámara del teléfono
    ret, frame = cap.read()

    if not ret:
        break  # Salir del bucle si no se puede capturar un fotograma

    # Run YOLOv8 inference on the frame
    results = model(frame)  # Asegúrate de tener tu modelo YOLOv8 definido previamente

    # Visualize the results on the frame
    annotated_frame = results[0].plot()

    # Display the annotated frame
    cv2.imshow("YOLOv8 Inference", annotated_frame)

    # Calcular el tiempo que lleva procesar este fotograma
    elapsed_time = time() - start_time

    # Calcular el retraso necesario para mantener una velocidad específica (por ejemplo, 30 FPS)
    delay = max(1, int((1 / target_fps - elapsed_time) * 1000))

    # Esperar el tiempo calculado
    cv2.waitKey(delay)

    # Actualizar el tiempo de referencia para el próximo fotograma
    start_time = time()

    # Si se presiona la tecla 'q', salir del bucle
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# %%
# Liberar la cámara y cerrar las ventanas
cap.release()
cv2.destroyAllWindows()

# %%
#!pip uninstall opencv-python
#!pip uninstall ultralytics

# %%
# !conda list

# %%
# !pip install opencv-python

# %%
# !pip install opencv-python-headless

# %%
# install https://www.msys2.org/
# install https://opencv.org/releases/
# install https://cmake.org/download/
# https://www.gtk.org/docs/installations/windows/

# %%
#pacman -S mingw-w64-x86_64-pkg-config
#pacman -S mingw-w64-x86_64-gtk2
#pacman -S mingw-w64-x86_64-gtk4

# %%
#!pip install cmake
